# %%
import pandas as pd
from pathlib import Path

# %%
artisan_df = pd.read_csv(Path(r"C:\Users\5th gen\artisan_data.csv"))

artisan_df.head()
# Out:
#        City Respondent Name  Age Martial State Education Level  \
# 0  Kandahar           Saima   33       Married        Bachelor
# 1  Kandahar           Atifa   23        Single      Uneducated
# 2  Kandahar     Gul Ghuncah   40       Widowed      Uneducated
# 3  Kandahar          Salima   38       Married      Uneducated
# 4  Kandahar         Ma Sima   56       Married    Diploma (14)
#
#   What type of handicraft your business is focused on?  \
# 0                                           Textile
# 1                                           Textile
# 2                                           Textile
# 3                                           Textile
# 4                                           Textile
#
#    How many years of experience do you have in this profession?  \
# 0                                                  6
# 1                                                  3
# 2                                                  5
# 3                                                  8
# 4                                                  6
#
#    If yes, how many years have passed since its establishment?  \
# 0                                                  3
# 1                                                  2
# 2                                                  5
# 3                                                  2
# 4                                                  3
#
#   Annual Income Range  \
# 0           10,000.00
# 1            5,000.00
# 2           30,000.00
# 3            2,000.00
# 4            5,000.00
#
#   Does the government or other actors provide tangible support or can this be expected?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Do you have a work permit? In which market are your products sold the most?  \
# 0                         No                       Village level Local Market
# 1                         No                                     Local Market
# 2                         No                                    Village level
# 3                         No                                    Village level
# 4                         No                       Village level Local Market
#
#   Local Market Foreign Market National Village Level
# 0          Yes            NaN      NaN           Yes
# 1          Yes            NaN      NaN           NaN
# 2          NaN            NaN      NaN           Yes
# 3          NaN            NaN      NaN           Yes
# 4          Yes            NaN      NaN           Yes

# %%
# Strip any whitespace and convert to string
artisan_df['Annual Income Range'] = artisan_df['Annual Income Range'].astype(str).str.strip()

# Replace the incorrect value 500000 with 100000
artisan_df['Annual Income Range'] = artisan_df['Annual Income Range'].replace('500000', '100000')

# Remove commas and convert to numeric
artisan_df['Annual Income Range'] = artisan_df['Annual Income Range'].str.replace(',', '').astype(float)

# Replace the incorrect value 500000 with 100000

# Strip any whitespace and convert to string
artisan_df['What type of handicraft your business is focused on?'] = artisan_df['What type of handicraft your business is focused on?'].astype(str).str.strip()
artisan_df['What type of handicraft your business is focused on?'] = artisan_df['What type of handicraft your business is focused on?'].replace('Carteps and Rugs', 'Carpets & Rugs')
artisan_df['What type of handicraft your business is focused on?'] = artisan_df['What type of handicraft your business is focused on?'].replace('Carpets and Rugs', 'Carpets & Rugs')
artisan_df['What type of handicraft your business is focused on?'] = artisan_df['What type of handicraft your business is focused on?'].replace('Leather work', 'Leatherwork')
artisan_df['What type of handicraft your business is focused on?'] = artisan_df['What type of handicraft your business is focused on?'].replace('Jewlery', 'Jewelry')
artisan_df['What type of handicraft your business is focused on?'] = artisan_df['What type of handicraft your business is focused on?'].replace('Textile', 'Textiles')
artisan_df
# Out:
#          City Respondent Name  Age Martial State   Education Level  \
# 0    Kandahar           Saima   33       Married          Bachelor
# 1    Kandahar           Atifa   23        Single        Uneducated
# 2    Kandahar     Gul Ghuncah   40       Widowed        Uneducated
# 3    Kandahar          Salima   38       Married        Uneducated
# 4    Kandahar         Ma Sima   56       Married      Diploma (14)
# ..        ...             ...  ...           ...               ...
# 295    Bamyan          Maryam   42       Married     Primary (1-6)
# 296    Bamyan        Hadeesah   17        Single      Middle (7-9)
# 297    Bamyan          Zahira   28       Married      Diploma (14)
# 298    Bamyan         Sakinah   18        Single  High school (12)
# 299    Bamyan           Qamar   34       Married      Middle (7-9)
#
#     What type of handicraft your business is focused on?  \
# 0                                             Textiles
# 1                                             Textiles
# 2                                             Textiles
# 3                                             Textiles
# 4                                             Textiles
# ..                                                 ...
# 295                                     Carpets & Rugs
# 296                                     Carpets & Rugs
# 297                                     Carpets & Rugs
# 298                                     Carpets & Rugs
# 299                                     Carpets & Rugs
#
#      How many years of experience do you have in this profession?  \
# 0                                                    6
# 1                                                    3
# 2                                                    5
# 3                                                    8
# 4                                                    6
# ..                                                 ...
# 295                                                 15
# 296                                                  3
# 297                                                 10
# 298                                                  4
# 299                                                 15
#
#      If yes, how many years have passed since its establishment?  \
# 0                                                    3
# 1                                                    2
# 2                                                    5
# 3                                                    2
# 4                                                    3
# ..                                                 ...
# 295                                                 15
# 296                                                  3
# 297                                                  5
# 298                                                  4
# 299                                                 15
#
#      Annual Income Range  \
# 0                10000.0
# 1                 5000.0
# 2                30000.0
# 3                 2000.0
# 4                 5000.0
# ..                   ...
# 295              40000.0
# 296              80000.0
# 297             200000.0
# 298              30000.0
# 299              10000.0
#
#     Does the government or other actors provide tangible support or can this be expected?  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ..                                                 ...
# 295                                                 No
# 296                                                 No
# 297                                                 No
# 298                                                 No
# 299                                                 No
#
#     Do you have a work permit?  \
# 0                           No
# 1                           No
# 2                           No
# 3                           No
# 4                           No
# ..                         ...
# 295                         No
# 296                         No
# 297                        Yes
# 298                         No
# 299                        Yes
#
#       In which market are your products sold the most? Local Market  \
# 0                           Village level Local Market          Yes
# 1                                         Local Market          Yes
# 2                                        Village level          NaN
# 3                                        Village level          NaN
# 4                           Village level Local Market          Yes
# ..                                                 ...          ...
# 295                       Village level Foreign Market          NaN
# 296  Foreign Market To other Provinces Local Market...          Yes
# 297                       Village level Foreign Market          NaN
# 298  Village level Local Market To other Provinces ...          Yes
# 299  Village level Local Market To other Provinces ...          Yes
#
#     Foreign Market National Village Level
# 0              NaN      NaN           Yes
# 1              NaN      NaN           NaN
# 2              NaN      NaN           Yes
# 3              NaN      NaN           Yes
# 4              NaN      NaN           Yes
# ..             ...      ...           ...
# 295            Yes      NaN           Yes
# 296            Yes      Yes           Yes
# 297            Yes      NaN           Yes
# 298            Yes      Yes           Yes
# 299            Yes      Yes           Yes
#
# [300 rows x 16 columns]

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd
import plotly.express as px

# %% [raw]
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()],
#         value='Kabul',
#         clearable=False
#     ),
#     dcc.Graph(id='age-income-scatter')
# ])
# # Callback to update the graph based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value')]
# )
# def update_graph(selected_city):
#     filtered_df = artisan_df[artisan_df['City'] == selected_city]
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', title=f'Age vs Income in {selected_city}')
#     return fig
#
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Graph(id='age-income-scatter')
# ])
#
# # Callback to update the graph based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value')]
# )
# def update_graph(selected_city):
#     if selected_city == 'All Cities':
#         filtered_df = artisan_df
#     else:
#         filtered_df = artisan_df[artisan_df['City'] == selected_city]
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='City', title='Age vs Income')
#     return fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Graph(id='age-income-scatter')
# ])
#
# # Callback to update the graph based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value')]
# )
# def update_graph(selected_city):
#     if selected_city == 'All Cities':
#         filtered_df = artisan_df
#         overall_avg_income = filtered_df['Annual Income Range'].mean()
#     else:
#         filtered_df = artisan_df[artisan_df['City'] == selected_city]
#         overall_avg_income = artisan_df['Annual Income Range'].mean()
#
#     # Create scatter plot
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='City', title=f'Age vs Income in {selected_city}')
#
#
#
#     # Add city-specific average line if not 'All Cities'
#     if selected_city != 'All Cities':
#         city_avg_income = filtered_df['Annual Income Range'].mean()
#         fig.add_shape(
#             type="line",
#             x0=filtered_df['Age'].min(),
#             x1=filtered_df['Age'].max(),
#             y0=city_avg_income,
#             y1=city_avg_income,
#             line=dict(color="Blue", width=2, dash="dot"),
#             name=f"{selected_city} Average"
#         )
#
#     return fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# import pandas as pd
# import plotly.express as px
# import dash
# import dash_core_components as dcc
# import dash_html_components as html
# from dash.dependencies import Input, Output
#
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Dropdown(
#         id='handicraft-dropdown',
#         options=[
#             {'label': 'Textiles', 'value': 'Textiles'},
#             {'label': 'Carpets & Rugs', 'value': 'Carpets & Rugs'},
#             {'label': 'Ceramics', 'value': 'Ceramics'},
#             {'label': 'Jewelry', 'value': 'Jewelry'},
#             {'label': 'Leatherwork', 'value': 'Leatherwork'}
#         ],
#         value='All Handicrafts',
#         clearable=False
#     ),
#     dcc.Graph(id='age-income-scatter')
# ])
#
# # Callback to update the graph based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_graph(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Handicrafts':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     overall_avg_income = artisan_df['Annual Income Range'].mean()
#
#     # Create scatter plot
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='City', title=f'Age vs Income')
#
#     # Add city-specific average line if not 'All Cities'
#     if selected_city != 'All Cities':
#         city_avg_income = filtered_df['Annual Income Range'].mean()
#         fig.add_shape(
#             type="line",
#             x0=filtered_df['Age'].min(),
#             x1=filtered_df['Age'].max(),
#             y0=city_avg_income,
#             y1=city_avg_income,
#             line=dict(color="Blue", width=2, dash="dot"),
#             name=f"{selected_city} Average"
#         )
#
#     return fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# import pandas as pd
# import plotly.express as px
# import dash
# import dash_core_components as dcc
# import dash_html_components as html
# from dash.dependencies import Input, Output
#
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Dropdown(
#         id='handicraft-dropdown',
#         options=[
#             {'label': 'All Categories', 'value': 'All Categories'},
#             {'label': 'Textiles', 'value': 'Textiles'},
#             {'label': 'Carpets & Rugs', 'value': 'Carpets & Rugs'},
#             {'label': 'Ceramics', 'value': 'Ceramics'},
#             {'label': 'Jewelry', 'value': 'Jewelry'},
#             {'label': 'Leatherwork', 'value': 'Leatherwork'}
#         ],
#         value='All Categories',
#         clearable=False
#     ),
#     dcc.Graph(id='age-income-scatter')
# ])
#
# # Callback to update the graph based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_graph(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     overall_avg_income = artisan_df['Annual Income Range'].mean()
#
#     # Create scatter plot with work permit status
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='Do you have a work permit?',
#                      title=f'Age vs Income in {selected_city} - {selected_handicraft}',
#                      labels={'Do you have a work permit?': 'Work Permit Status'})
#
#     # Add overall average line
#     fig.add_shape(
#         type="line",
#         x0=filtered_df['Age'].min(),
#         x1=filtered_df['Age'].max(),
#         y0=overall_avg_income,
#         y1=overall_avg_income,
#         line=dict(color="Red", width=2, dash="dash"),
#         name="Overall Average"
#     )
#
#     # Add city-specific average line if not 'All Cities'
#     if selected_city != 'All Cities':
#         city_avg_income = filtered_df['Annual Income Range'].mean()
#         fig.add_shape(
#             type="line",
#             x0=filtered_df['Age'].min(),
#             x1=filtered_df['Age'].max(),
#             y0=city_avg_income,
#             y1=city_avg_income,
#             line=dict(color="Blue", width=2, dash="dot"),
#             name=f"{selected_city} Average"
#         )
#
#     return fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# import pandas as pd
# import plotly.express as px
# import dash
# import dash_core_components as dcc
# import dash_html_components as html
# from dash.dependencies import Input, Output
#
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Dropdown(
#         id='handicraft-dropdown',
#         options=[
#             {'label': 'All Categories', 'value': 'All Categories'},
#             {'label': 'Textiles', 'value': 'Textiles'},
#             {'label': 'Carpets & Rugs', 'value': 'Carpets & Rugs'},
#             {'label': 'Ceramics', 'value': 'Ceramics'},
#             {'label': 'Jewelry', 'value': 'Jewelry'},
#             {'label': 'Leatherwork', 'value': 'Leatherwork'}
#         ],
#         value='All Categories',
#         clearable=False
#     ),
#     dcc.Graph(id='age-income-scatter')
# ])
#
# # Callback to update the graph based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_graph(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     # Count the number of "Yes" and "No" for work permits
#     work_permit_counts = filtered_df['Do you have a work permit?'].value_counts().to_dict()
#     count_yes = work_permit_counts.get('Yes', 0)
#     count_no = work_permit_counts.get('No', 0)
#
#     # Create scatter plot with work permit status
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='Do you have a work permit?',
#                      title=f'Age vs Income in {selected_city} - {selected_handicraft}',
#                      labels={'Do you have a work permit?': 'Work Permit Status'})
#
#     # Add overall average line
#     overall_avg_income = artisan_df['Annual Income Range'].mean()
#     fig.add_shape(
#         type="line",
#         x0=filtered_df['Age'].min(),
#         x1=filtered_df['Age'].max(),
#         y0=overall_avg_income,
#         y1=overall_avg_income,
#         line=dict(color="Red", width=2, dash="dash"),
#         name="Overall Average"
#     )
#
#     # Add city-specific average line if not 'All Cities'
#     if selected_city != 'All Cities':
#         city_avg_income = filtered_df['Annual Income Range'].mean()
#         fig.add_shape(
#             type="line",
#             x0=filtered_df['Age'].min(),
#             x1=filtered_df['Age'].max(),
#             y0=city_avg_income,
#             y1=city_avg_income,
#             line=dict(color="Blue", width=2, dash="dot"),
#             name=f"{selected_city} Average"
#         )
#
#     # Update hover template to include work permit counts
#     fig.update_traces(
#         hovertemplate=
#         'Age: %{x}<br>' +
#         'Income: %{y}<br>' +
#
#         'Yes: ' + str(count_yes) + '<br>' +
#         'No: ' + str(count_no)
#     )
#
#     return fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# import pandas as pd
# import plotly.express as px
# import dash
# import dash_core_components as dcc
# import dash_html_components as html
# from dash.dependencies import Input, Output
#
#
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Dropdown(
#         id='handicraft-dropdown',
#         options=[
#             {'label': 'All Categories', 'value': 'All Categories'},
#             {'label': 'Textiles', 'value': 'Textiles'},
#             {'label': 'Carpets & Rugs', 'value': 'Carpets & Rugs'},
#             {'label': 'Ceramics', 'value': 'Ceramics'},
#             {'label': 'Jewelry', 'value': 'Jewelry'},
#             {'label': 'Leatherwork', 'value': 'Leatherwork'}
#         ],
#         value='All Categories',
#         clearable=False
#     ),
#     dcc.Graph(id='age-income-scatter'),
#     dcc.Graph(id='category-bar-chart')
# ])
#
# # Callback to update the graph based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_graph(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     # Count the number of "Yes" and "No" for work permits in the filtered data
#     work_permit_counts = filtered_df['Do you have a work permit?'].value_counts().to_dict()
#     count_yes = work_permit_counts.get('Yes', 0)
#     count_no = work_permit_counts.get('No', 0)
#
#     # Map the counts to the 'Do you have a work permit?' column in the filtered data
#     filtered_df['Work Permit Status'] = filtered_df['Do you have a work permit?'].map(
#         lambda x: f'{x} ({work_permit_counts.get(x, 0)})'
#     )
#
#     # Create scatter plot with work permit status
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='Work Permit Status',
#                      title=f'Age vs Income in {selected_city} - {selected_handicraft}',
#                      labels={'Work Permit Status': 'Work Permit Status'})
#
#     # Add overall average line
#     overall_avg_income = artisan_df['Annual Income Range'].mean()
#     fig.add_shape(
#         type="line",
#         x0=filtered_df['Age'].min(),
#         x1=filtered_df['Age'].max(),
#         y0=overall_avg_income,
#         y1=overall_avg_income,
#         line=dict(color="Red", width=2, dash="dash"),
#         name="Overall Average"
#     )
#
#     # Add city-specific average line if not 'All Cities'
#     if selected_city != 'All Cities':
#         city_avg_income = filtered_df['Annual Income Range'].mean()
#         fig.add_shape(
#             type="line",
#             x0=filtered_df['Age'].min(),
#             x1=filtered_df['Age'].max(),
#             y0=city_avg_income,
#             y1=city_avg_income,
#             line=dict(color="Blue", width=2, dash="dot"),
#             name=f"{selected_city} Average"
#         )
#
#     return fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Dropdown(
#         id='handicraft-dropdown',
#         options=[
#             {'label': 'All Categories', 'value': 'All Categories'},
#             {'label': 'Textiles', 'value': 'Textiles'},
#             {'label': 'Carpets & Rugs', 'value': 'Carpets & Rugs'},
#             {'label': 'Ceramics', 'value': 'Ceramics'},
#             {'label': 'Jewelry', 'value': 'Jewelry'},
#             {'label': 'Leatherwork', 'value': 'Leatherwork'}
#         ],
#         value='All Categories',
#         clearable=False
#     ),
#     dcc.Graph(id='age-income-scatter'),
#     dcc.Graph(id='category-bar-chart')
# ])
#
# # Callback to update the scatter plot based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_scatter_plot(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     # Count the number of "Yes" and "No" for work permits in the filtered data
#     work_permit_counts = filtered_df['Do you have a work permit?'].value_counts().to_dict()
#
#     # Ensure that the filtered data is updated correctly with the counts
#     filtered_df['Work Permit Status'] = filtered_df['Do you have a work permit?'].map(
#         lambda x: f'{x} ({work_permit_counts.get(x, 0)})'
#     )
#
#     # Create scatter plot with work permit status
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='Work Permit Status',
#                      title=f'Age vs Income in {selected_city} - {selected_handicraft}',
#                      labels={'Work Permit Status': 'Work Permit Status'})
#
#     # Add overall average line
#     overall_avg_income = artisan_df['Annual Income Range'].mean()
#     fig.add_shape(
#         type="line",
#         x0=filtered_df['Age'].min(),
#         x1=filtered_df['Age'].max(),
#         y0=overall_avg_income,
#         y1=overall_avg_income,
#         line=dict(color="Red", width=2, dash="dash"),
#         name="Overall Average"
#     )
#
#     # Add city-specific average line if not 'All Cities'
#     if selected_city != 'All Cities':
#         city_avg_income = filtered_df['Annual Income Range'].mean()
#         fig.add_shape(
#             type="line",
#             x0=filtered_df['Age'].min(),
#             x1=filtered_df['Age'].max(),
#             y0=city_avg_income,
#             y1=city_avg_income,
#             line=dict(color="Blue", width=2, dash="dot"),
#             name=f"{selected_city} Average"
#         )
#
#     return fig
#
# # Callback to update the bar chart based on dropdown selection
# @app.callback(
#     Output('category-bar-chart', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_bar_chart(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     # Create bar chart for the number of values in each category by province
#     bar_fig = px.bar(filtered_df, x='What type of handicraft your business is focused on?', color='City',
#                      title=f'Number of Values in Each Category by {selected_city}',
#                      labels={'What type of handicraft your business is focused on?': 'Handicraft Category'})
#
#     return bar_fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Dropdown(
#         id='handicraft-dropdown',
#         options=[
#             {'label': 'All Categories', 'value': 'All Categories'},
#             {'label': 'Textiles', 'value': 'Textiles'},
#             {'label': 'Carpets & Rugs', 'value': 'Carpets & Rugs'},
#             {'label': 'Ceramics', 'value': 'Ceramics'},
#             {'label': 'Jewelry', 'value': 'Jewelry'},
#             {'label': 'Leatherwork', 'value': 'Leatherwork'}
#         ],
#         value='All Categories',
#         clearable=False
#     ),
#     html.Div([
#         dcc.Graph(id='age-income-scatter', style={'width': '70%', 'display': 'inline-block'}),
#         dcc.Graph(id='category-bar-chart', style={'width': '30%', 'display': 'inline-block'})
#     ])
# ])
#
# # Callback to update the scatter plot based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_scatter_plot(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     # Count the number of "Yes" and "No" for work permits in the filtered data
#     work_permit_counts = filtered_df['Do you have a work permit?'].value_counts().to_dict()
#
#     # Ensure that the filtered data is updated correctly with the counts
#     filtered_df['Work Permit Status'] = filtered_df['Do you have a work permit?'].map(
#         lambda x: f'{x} ({work_permit_counts.get(x, 0)})'
#     )
#
#     # Create scatter plot with work permit status
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='Work Permit Status',
#                      title=f'Age vs Income in {selected_city} - {selected_handicraft}',
#                      labels={'Work Permit Status': 'Work Permit Status'})
#
#     # Add overall average line
#     overall_avg_income = artisan_df['Annual Income Range'].mean()
#     fig.add_shape(
#         type="line",
#         x0=filtered_df['Age'].min(),
#         x1=filtered_df['Age'].max(),
#         y0=overall_avg_income,
#         y1=overall_avg_income,
#         line=dict(color="Red", width=2, dash="dash"),
#         name="Overall Average"
#     )
#
#     # Add city-specific average line if not 'All Cities'
#     if selected_city != 'All Cities':
#         city_avg_income = filtered_df['Annual Income Range'].mean()
#         fig.add_shape(
#             type="line",
#             x0=filtered_df['Age'].min(),
#             x1=filtered_df['Age'].max(),
#             y0=city_avg_income,
#             y1=city_avg_income,
#             line=dict(color="Blue", width=2, dash="dot"),
#             name=f"{selected_city} Average"
#         )
#
#     return fig
#
# # Callback to update the bar chart based on dropdown selection
# @app.callback(
#     Output('category-bar-chart', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_bar_chart(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     # Create bar chart for the number of values in each category by province
#     bar_fig = px.bar(filtered_df, x='What type of handicraft your business is focused on?', color='City',
#                      title=f'Number of Values in Each Category by {selected_city}',
#                      labels={'What type of handicraft your business is focused on?': 'Handicraft Category'})
#
#     return bar_fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %% [raw]
# # Initialize the Dash app
# app = dash.Dash(__name__)
#
# # Layout of the Dash app
# app.layout = html.Div([
#     html.H1("Interactive Dashboard"),
#     dcc.Dropdown(
#         id='city-dropdown',
#         options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
#         value='All Cities',
#         clearable=False
#     ),
#     dcc.Dropdown(
#         id='handicraft-dropdown',
#         options=[
#             {'label': 'All Categories', 'value': 'All Categories'},
#             {'label': 'Textiles', 'value': 'Textiles'},
#             {'label': 'Carpets & Rugs', 'value': 'Carpets & Rugs'},
#             {'label': 'Ceramics', 'value': 'Ceramics'},
#             {'label': 'Jewelry', 'value': 'Jewelry'},
#             {'label': 'Leatherwork', 'value': 'Leatherwork'}
#         ],
#         value='All Categories',
#         clearable=False
#     ),
#     html.Div([
#         dcc.Graph(id='age-income-scatter', style={'width': '70%', 'display': 'inline-block'}),
#         dcc.Graph(id='category-bar-chart', style={'width': '30%', 'display': 'inline-block'})
#     ])
# ])
#
# # Callback to update the scatter plot based on dropdown selection
# @app.callback(
#     Output('age-income-scatter', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_scatter_plot(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     # Count the number of "Yes" and "No" for work permits in the filtered data
#     work_permit_counts = filtered_df['Do you have a work permit?'].value_counts().to_dict()
#
#     # Ensure that the filtered data is updated correctly with the counts
#     filtered_df['Work Permit Status'] = filtered_df['Do you have a work permit?'].map(
#         lambda x: f'{x} ({work_permit_counts.get(x, 0)})'
#     )
#
#     # Create scatter plot with work permit status
#     fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='Work Permit Status',
#                      title=f'Age vs Income in {selected_city} - {selected_handicraft}',
#                      labels={'Work Permit Status': 'Work Permit Status'})
#
#     # Add overall average line
#     overall_avg_income = artisan_df['Annual Income Range'].mean()
#     fig.add_shape(
#         type="line",
#         x0=filtered_df['Age'].min(),
#         x1=filtered_df['Age'].max(),
#         y0=overall_avg_income,
#         y1=overall_avg_income,
#         line=dict(color="Red", width=2, dash="dash"),
#         name="Overall Average"
#     )
#
#     # Add city-specific average line if not 'All Cities'
#     if selected_city != 'All Cities':
#         city_avg_income = filtered_df['Annual Income Range'].mean()
#         fig.add_shape(
#             type="line",
#             x0=filtered_df['Age'].min(),
#             x1=filtered_df['Age'].max(),
#             y0=city_avg_income,
#             y1=city_avg_income,
#             line=dict(color="Blue", width=2, dash="dot"),
#             name=f"{selected_city} Average"
#         )
#
#     return fig
#
# # Callback to update the bar chart based on dropdown selection
# @app.callback(
#     Output('category-bar-chart', 'figure'),
#     [Input('city-dropdown', 'value'),
#      Input('handicraft-dropdown', 'value')]
# )
# def update_bar_chart(selected_city, selected_handicraft):
#     filtered_df = artisan_df
#
#     if selected_city != 'All Cities':
#         filtered_df = filtered_df[filtered_df['City'] == selected_city]
#
#     if selected_handicraft != 'All Categories':
#         filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]
#
#     # Group by handicraft category and count occurrences
#     category_counts = filtered_df['What type of handicraft your business is focused on?'].value_counts().reset_index()
#     category_counts.columns = ['Handicraft Category', 'Count']
#
#     # Create bar chart for the number of values in each category by province
#     bar_fig = px.bar(category_counts, x='Handicraft Category', y='Count', color='Handicraft Category',
#                      title=f'Number of Values in Each Category by {selected_city}')
#
#     return bar_fig
#
# # Run the app on a different port
# if __name__ == '__main__':
#     app.run_server(debug=True, port=8051)

# %%
import pandas as pd
import plotly.express as px
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# Initialize the Dash app
app = dash.Dash(__name__)

# Layout of the Dash app
app.layout = html.Div([
    html.H1("Interactive Dashboard"),
    dcc.Dropdown(
        id='city-dropdown',
        options=[{'label': city, 'value': city} for city in artisan_df['City'].unique()] + [{'label': 'All Cities', 'value': 'All Cities'}],
        value='All Cities',
        clearable=False
    ),
    dcc.Dropdown(
        id='handicraft-dropdown',
        options=[
            {'label': 'All Categories', 'value': 'All Categories'},
            {'label': 'Textiles', 'value': 'Textiles'},
            {'label': 'Carpets & Rugs', 'value': 'Carpets & Rugs'},
            {'label': 'Ceramics', 'value': 'Ceramics'},
            {'label': 'Jewelry', 'value': 'Jewelry'},
            {'label': 'Leatherwork', 'value': 'Leatherwork'}
        ],
        value='All Categories',
        clearable=False
    ),
    html.Div([
        dcc.Graph(id='age-income-scatter', style={'width': '100%', 'display': 'inline-block'}),
        dcc.Graph(id='category-bar-chart', style={'width': '50%', 'display': 'inline-block'}),
        dcc.Graph(id='market-bar-chart', style={'width': '50%', 'display': 'inline-block'})
    
        
    ])
])

# Callback to update the scatter plot based on dropdown selection
@app.callback(
    Output('age-income-scatter', 'figure'),
    [Input('city-dropdown', 'value'),
     Input('handicraft-dropdown', 'value')]
)
def update_scatter_plot(selected_city, selected_handicraft):
    filtered_df = artisan_df

    if selected_city != 'All Cities':
        filtered_df = filtered_df[filtered_df['City'] == selected_city]

    if selected_handicraft != 'All Categories':
        filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]

    # Count the number of "Yes" and "No" for work permits in the filtered data
    work_permit_counts = filtered_df['Do you have a work permit?'].value_counts().to_dict()

    # Ensure that the filtered data is updated correctly with the counts
    filtered_df['Work Permit Status'] = filtered_df['Do you have a work permit?'].map(
        lambda x: f'{x} ({work_permit_counts.get(x, 0)})'
    )

    # Create scatter plot with work permit status
    fig = px.scatter(filtered_df, x='Age', y='Annual Income Range', color='Work Permit Status', 
                     title=f'Age vs Income in {selected_city} - {selected_handicraft}',
                     labels={'Work Permit Status': 'Work Permit Status'})

    # Add overall average line
    overall_avg_income = artisan_df['Annual Income Range'].mean()
    fig.add_shape(
        type="line",
        x0=filtered_df['Age'].min(),
        x1=filtered_df['Age'].max(),
        y0=overall_avg_income,
        y1=overall_avg_income,
        line=dict(color="Red", width=2, dash="dash"),
        name="Overall Average"
    )

    # Add city-specific average line if not 'All Cities'
    if selected_city != 'All Cities':
        city_avg_income = filtered_df['Annual Income Range'].mean()
        fig.add_shape(
            type="line",
            x0=filtered_df['Age'].min(),
            x1=filtered_df['Age'].max(),
            y0=city_avg_income,
            y1=city_avg_income,
            line=dict(color="Blue", width=2, dash="dot"),
            name=f"{selected_city} Average"
        )

    return fig

# Callback to update the category bar chart based on dropdown selection
@app.callback(
    Output('category-bar-chart', 'figure'),
    [Input('city-dropdown', 'value'),
     Input('handicraft-dropdown', 'value')]
)
def update_bar_chart(selected_city, selected_handicraft):
    filtered_df = artisan_df

    if selected_city != 'All Cities':
        filtered_df = filtered_df[filtered_df['City'] == selected_city]

    if selected_handicraft != 'All Categories':
        filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]

    # Group by handicraft category and count occurrences
    category_counts = filtered_df['What type of handicraft your business is focused on?'].value_counts().reset_index()
    category_counts.columns = ['Handicraft Category', 'Count']

    # Create bar chart for the number of values in each category by province
    bar_fig = px.bar(category_counts, x='Handicraft Category', y='Count', color='Handicraft Category',
                     title=f'Number of Values in Each Category by {selected_city}')

    return bar_fig

# Callback to update the market bar chart based on dropdown selection
@app.callback(
    Output('market-bar-chart', 'figure'),
    [Input('city-dropdown', 'value'),
     Input('handicraft-dropdown', 'value')]
)
def update_market_bar_chart(selected_city, selected_handicraft):
    filtered_df = artisan_df

    if selected_city != 'All Cities':
        filtered_df = filtered_df[filtered_df['City'] == selected_city]

    if selected_handicraft != 'All Categories':
        filtered_df = filtered_df[filtered_df['What type of handicraft your business is focused on?'] == selected_handicraft]

    # Count occurrences of "Yes" for each market type
    market_counts = {
        'Local Market': filtered_df['Local Market'].value_counts().get('Yes', 0),
        'Foreign Market': filtered_df['Foreign Market'].value_counts().get('Yes', 0),
        'National': filtered_df['National'].value_counts().get('Yes', 0),
        'Village Level': filtered_df['Village Level'].value_counts().get('Yes', 0)
    }

    market_counts_df = pd.DataFrame(list(market_counts.items()), columns=['Market Type', 'Count'])

    # Create bar chart for the number of values in each market type
    market_bar_fig = px.bar(market_counts_df, x='Market Type', y='Count', color='Market Type',
                            title=f'Number of Values in Each Market by {selected_city}')

    return market_bar_fig

# Run the app on a different port
if __name__ == '__main__':
    app.run_server(debug=True, port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
